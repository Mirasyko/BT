# %%
import numpy as np
import pandas as pd

# %%
import os
import pandas as pd
import numpy as np
import time

import utils as ut
from heuristics import run_genetic_algorithm, evaluate_matrix, simulated_annealing, hill_climb, run_fixed_link_ga
from dynamic_weights import linear_flow_int, linear_flow
from static_weights import milp_static_model, lp_static_model





m             = 7
start_day     = 30
end_day       = 80
results        = []   
excess_df, deficit_df, _ = ut.real_dataset(m, start_day, end_day)


W_optimal, links_milp, milp_model = milp_static_model(
    excess_df, deficit_df, time_limit=500000
)


best_M, best_fit = run_fixed_link_ga(
    link_df=links_milp,
    weights=W_optimal,
    excess_df=excess_df,
    deficit_df=deficit_df,
    generations=1,
    population_size=5,
    mutation_rate=0.2,
    crossover_rate=0.9
)

print(best_M, best_fit)
print(W_optimal)
# Out:
# Set parameter Username
# Set parameter LicenseID to value 2652867
# Academic license - for non-commercial use only - expires 2026-04-15
#                        zs_preislerova  zs_komenskeho  ms_preislerova  \
# zs_preislerova                    0.0            0.0             0.0
# zs_komenskeho                     0.0            0.0             1.0
# ms_preislerova                    0.0            0.0             0.0
# ms_pod_homolkou                   2.0            0.0             0.0
# ms_vrchlickeho                    0.0            0.0             0.0
# ms_drasarova                      0.0            0.0             0.0
# ms_na_machovne                    0.0            0.0             0.0
# zimni_stad                        2.0            0.0             3.0
# parkovaci_dum                     0.0            0.0             0.0
# radnice                           0.0            0.0             2.0
# ms_tovarni                        0.0            0.0             2.0
# dum_pro_duchodce                  0.0            0.0             1.0
# plavecky_areal                    0.0            0.0             4.0
# pristavba_preislerova             0.0            0.0             0.0
#
#                        ms_pod_homolkou  ms_vrchlickeho  ms_drasarova  \
# zs_preislerova                     2.0             5.0           1.0
# zs_komenskeho                      0.0             0.0           0.0
# ms_preislerova                     0.0             0.0           0.0
# ms_pod_homolkou                    0.0             5.0           3.0
# ms_vrchlickeho                     0.0             0.0           0.0
# ms_drasarova                       0.0             0.0           0.0
# ms_na_machovne                     0.0             0.0           0.0
# zimni_stad                         1.0             0.0           0.0
# parkovaci_dum                      0.0             0.0           0.0
# radnice                            0.0             0.0           0.0
# ms_tovarni                         1.0             0.0           0.0
# dum_pro_duchodce                   0.0             0.0           0.0
# plavecky_areal                     0.0             1.0           3.0
# pristavba_preislerova              0.0             0.0           0.0
#
#                        ms_na_machovne  zimni_stad  parkovaci_dum  radnice  \
# zs_preislerova                    4.0         0.0            0.0      0.0
# zs_komenskeho                     0.0         0.0            2.0      0.0
# ms_preislerova                    0.0         0.0            0.0      0.0
# ms_pod_homolkou                   1.0         0.0            0.0      0.0
# ms_vrchlickeho                    0.0         0.0            0.0      0.0
# ms_drasarova                      0.0         0.0            0.0      0.0
# ms_na_machovne                    0.0         0.0            0.0      0.0
# zimni_stad                        0.0         0.0            0.0      0.0
# parkovaci_dum                     0.0         0.0            0.0      0.0
# radnice                           0.0         1.0            0.0      0.0
# ms_tovarni                        0.0         0.0            0.0      0.0
# dum_pro_duchodce                  0.0         0.0            0.0      0.0
# plavecky_areal                    2.0         0.0            0.0      0.0
# pristavba_preislerova             0.0         0.0            0.0      0.0
#
#                        ms_tovarni  dum_pro_duchodce  plavecky_areal  \
# zs_preislerova                0.0               0.0             0.0
# zs_komenskeho                 0.0               0.0             0.0
# ms_preislerova                0.0               0.0             0.0
# ms_pod_homolkou               0.0               0.0             0.0
# ms_vrchlickeho                0.0               0.0             0.0
# ms_drasarova                  0.0               0.0             0.0
# ms_na_machovne                0.0               0.0             0.0
# zimni_stad                    0.0               0.0             0.0
# parkovaci_dum                 0.0               0.0             0.0
# radnice                       0.0               0.0             0.0
# ms_tovarni                    0.0               0.0             0.0
# dum_pro_duchodce              0.0               0.0             0.0
# plavecky_areal                0.0               0.0             0.0
# pristavba_preislerova         0.0               0.0             0.0
#
#                        pristavba_preislerova
# zs_preislerova                           3.0
# zs_komenskeho                            0.0
# ms_preislerova                           0.0
# ms_pod_homolkou                          4.0
# ms_vrchlickeho                           0.0
# ms_drasarova                             0.0
# ms_na_machovne                           0.0
# zimni_stad                               0.0
# parkovaci_dum                            0.0
# radnice                                  0.0
# ms_tovarni                               0.0
# dum_pro_duchodce                         0.0
# plavecky_areal                           5.0
# pristavba_preislerova                    0.0   6.465165039849502
#                        zs_preislerova  zs_komenskeho  ms_preislerova  \
# zs_preislerova                   -0.0           -0.0           -0.00
# zs_komenskeho                     0.0           -0.0            0.00
# ms_preislerova                    0.0           -0.0           -0.00
# ms_pod_homolkou                   0.0           -0.0           -0.00
# ms_vrchlickeho                   -0.0           -0.0           -0.00
# ms_drasarova                     -0.0           -0.0           -0.00
# ms_na_machovne                   -0.0           -0.0           -0.00
# zimni_stad                        1.0            0.0            0.07
# parkovaci_dum                     0.0           -0.0            0.00
# radnice                           0.0            0.0            0.20
# ms_tovarni                        0.0            0.0            0.02
# dum_pro_duchodce                  0.0            0.0            0.01
# plavecky_areal                    0.0            0.0            0.70
# pristavba_preislerova            -0.0           -0.0           -0.00
#
#                        ms_pod_homolkou  ms_vrchlickeho  ms_drasarova  \
# zs_preislerova                    0.00             0.0           0.0
# zs_komenskeho                     0.00             0.0           0.0
# ms_preislerova                    0.00             0.0           0.0
# ms_pod_homolkou                  -0.00             0.0           0.0
# ms_vrchlickeho                   -0.00            -0.0          -0.0
# ms_drasarova                     -0.00            -0.0          -0.0
# ms_na_machovne                   -0.00            -0.0          -0.0
# zimni_stad                        0.99             0.0           0.0
# parkovaci_dum                     0.00             0.0           0.0
# radnice                           0.00             0.0           0.0
# ms_tovarni                        0.01             0.0           0.0
# dum_pro_duchodce                  0.00             0.0           0.0
# plavecky_areal                    0.00             1.0           1.0
# pristavba_preislerova            -0.00            -0.0          -0.0
#
#                        ms_na_machovne  zimni_stad  parkovaci_dum  radnice  \
# zs_preislerova                    0.0       -0.00          -0.00     -0.0
# zs_komenskeho                     0.0        0.00           0.01     -0.0
# ms_preislerova                    0.0       -0.00          -0.00     -0.0
# ms_pod_homolkou                   0.0       -0.00          -0.00     -0.0
# ms_vrchlickeho                   -0.0       -0.00          -0.00     -0.0
# ms_drasarova                     -0.0       -0.00          -0.00     -0.0
# ms_na_machovne                   -0.0       -0.00          -0.00     -0.0
# zimni_stad                        0.0       -0.00           0.00     -0.0
# parkovaci_dum                     0.0       -0.00          -0.00     -0.0
# radnice                           0.0        0.75           0.00     -0.0
# ms_tovarni                        0.0        0.00           0.00     -0.0
# dum_pro_duchodce                  0.0        0.00           0.00     -0.0
# plavecky_areal                    1.0        0.00           0.00     -0.0
# pristavba_preislerova            -0.0       -0.00          -0.00     -0.0
#
#                        ms_tovarni  dum_pro_duchodce  plavecky_areal  \
# zs_preislerova               -0.0              -0.0            -0.0
# zs_komenskeho                -0.0              -0.0            -0.0
# ms_preislerova               -0.0              -0.0            -0.0
# ms_pod_homolkou              -0.0              -0.0            -0.0
# ms_vrchlickeho               -0.0              -0.0            -0.0
# ms_drasarova                 -0.0              -0.0            -0.0
# ms_na_machovne               -0.0              -0.0            -0.0
# zimni_stad                   -0.0              -0.0            -0.0
# parkovaci_dum                -0.0              -0.0            -0.0
# radnice                      -0.0              -0.0            -0.0
# ms_tovarni                   -0.0              -0.0            -0.0
# dum_pro_duchodce             -0.0              -0.0            -0.0
# plavecky_areal               -0.0              -0.0            -0.0
# pristavba_preislerova        -0.0              -0.0            -0.0
#
#                        pristavba_preislerova
# zs_preislerova                           0.0
# zs_komenskeho                            0.0
# ms_preislerova                           0.0
# ms_pod_homolkou                          0.0
# ms_vrchlickeho                          -0.0
# ms_drasarova                            -0.0
# ms_na_machovne                          -0.0
# zimni_stad                               0.0
# parkovaci_dum                            0.0
# radnice                                  0.0
# ms_tovarni                               0.0
# dum_pro_duchodce                         0.0
# plavecky_areal                           1.0
# pristavba_preislerova                   -0.0

# %%
W_optimal
# Out:
#                        zs_preislerova  zs_komenskeho  ms_preislerova  \
# zs_preislerova                   -0.0           -0.0           -0.00
# zs_komenskeho                     0.0           -0.0            0.00
# ms_preislerova                    0.0           -0.0           -0.00
# ms_pod_homolkou                   0.0           -0.0           -0.00
# ms_vrchlickeho                   -0.0           -0.0           -0.00
# ms_drasarova                     -0.0           -0.0           -0.00
# ms_na_machovne                   -0.0           -0.0           -0.00
# zimni_stad                        1.0            0.0            0.07
# parkovaci_dum                     0.0           -0.0            0.00
# radnice                           0.0            0.0            0.20
# ms_tovarni                        0.0            0.0            0.02
# dum_pro_duchodce                  0.0            0.0            0.01
# plavecky_areal                    0.0            0.0            0.70
# pristavba_preislerova            -0.0           -0.0           -0.00
#
#                        ms_pod_homolkou  ms_vrchlickeho  ms_drasarova  \
# zs_preislerova                    0.00             0.0           0.0
# zs_komenskeho                     0.00             0.0           0.0
# ms_preislerova                    0.00             0.0           0.0
# ms_pod_homolkou                  -0.00             0.0           0.0
# ms_vrchlickeho                   -0.00            -0.0          -0.0
# ms_drasarova                     -0.00            -0.0          -0.0
# ms_na_machovne                   -0.00            -0.0          -0.0
# zimni_stad                        0.99             0.0           0.0
# parkovaci_dum                     0.00             0.0           0.0
# radnice                           0.00             0.0           0.0
# ms_tovarni                        0.01             0.0           0.0
# dum_pro_duchodce                  0.00             0.0           0.0
# plavecky_areal                    0.00             1.0           1.0
# pristavba_preislerova            -0.00            -0.0          -0.0
#
#                        ms_na_machovne  zimni_stad  parkovaci_dum  radnice  \
# zs_preislerova                    0.0       -0.00          -0.00     -0.0
# zs_komenskeho                     0.0        0.00           0.01     -0.0
# ms_preislerova                    0.0       -0.00          -0.00     -0.0
# ms_pod_homolkou                   0.0       -0.00          -0.00     -0.0
# ms_vrchlickeho                   -0.0       -0.00          -0.00     -0.0
# ms_drasarova                     -0.0       -0.00          -0.00     -0.0
# ms_na_machovne                   -0.0       -0.00          -0.00     -0.0
# zimni_stad                        0.0       -0.00           0.00     -0.0
# parkovaci_dum                     0.0       -0.00          -0.00     -0.0
# radnice                           0.0        0.75           0.00     -0.0
# ms_tovarni                        0.0        0.00           0.00     -0.0
# dum_pro_duchodce                  0.0        0.00           0.00     -0.0
# plavecky_areal                    1.0        0.00           0.00     -0.0
# pristavba_preislerova            -0.0       -0.00          -0.00     -0.0
#
#                        ms_tovarni  dum_pro_duchodce  plavecky_areal  \
# zs_preislerova               -0.0              -0.0            -0.0
# zs_komenskeho                -0.0              -0.0            -0.0
# ms_preislerova               -0.0              -0.0            -0.0
# ms_pod_homolkou              -0.0              -0.0            -0.0
# ms_vrchlickeho               -0.0              -0.0            -0.0
# ms_drasarova                 -0.0              -0.0            -0.0
# ms_na_machovne               -0.0              -0.0            -0.0
# zimni_stad                   -0.0              -0.0            -0.0
# parkovaci_dum                -0.0              -0.0            -0.0
# radnice                      -0.0              -0.0            -0.0
# ms_tovarni                   -0.0              -0.0            -0.0
# dum_pro_duchodce             -0.0              -0.0            -0.0
# plavecky_areal               -0.0              -0.0            -0.0
# pristavba_preislerova        -0.0              -0.0            -0.0
#
#                        pristavba_preislerova
# zs_preislerova                           0.0
# zs_komenskeho                            0.0
# ms_preislerova                           0.0
# ms_pod_homolkou                          0.0
# ms_vrchlickeho                          -0.0
# ms_drasarova                            -0.0
# ms_na_machovne                          -0.0
# zimni_stad                               0.0
# parkovaci_dum                            0.0
# radnice                                  0.0
# ms_tovarni                               0.0
# dum_pro_duchodce                         0.0
# plavecky_areal                           1.0
# pristavba_preislerova                   -0.0

# %%
links_milp
# Out:
#                        zs_preislerova  zs_komenskeho  ms_preislerova  \
# zs_preislerova                    0.0            0.0             0.0
# zs_komenskeho                     0.0            0.0             1.0
# ms_preislerova                    0.0            0.0             0.0
# ms_pod_homolkou                   1.0            0.0             0.0
# ms_vrchlickeho                    0.0            0.0             0.0
# ms_drasarova                      0.0            0.0             0.0
# ms_na_machovne                    0.0            0.0             0.0
# zimni_stad                        1.0            0.0             1.0
# parkovaci_dum                     0.0            0.0             0.0
# radnice                           0.0            0.0             1.0
# ms_tovarni                        0.0            0.0             1.0
# dum_pro_duchodce                  0.0            0.0             1.0
# plavecky_areal                    0.0            0.0             1.0
# pristavba_preislerova             0.0            0.0             0.0
#
#                        ms_pod_homolkou  ms_vrchlickeho  ms_drasarova  \
# zs_preislerova                     1.0             1.0           1.0
# zs_komenskeho                      0.0             0.0           0.0
# ms_preislerova                     0.0             0.0           0.0
# ms_pod_homolkou                    0.0             1.0           1.0
# ms_vrchlickeho                     0.0             0.0           0.0
# ms_drasarova                       0.0             0.0           0.0
# ms_na_machovne                     0.0             0.0           0.0
# zimni_stad                         1.0             0.0           0.0
# parkovaci_dum                      0.0             0.0           0.0
# radnice                            0.0             0.0           0.0
# ms_tovarni                         1.0             0.0           0.0
# dum_pro_duchodce                   0.0             0.0           0.0
# plavecky_areal                     0.0             1.0           1.0
# pristavba_preislerova              0.0             0.0           0.0
#
#                        ms_na_machovne  zimni_stad  parkovaci_dum  radnice  \
# zs_preislerova                    1.0         0.0            0.0      0.0
# zs_komenskeho                     0.0         0.0            1.0      0.0
# ms_preislerova                    0.0         0.0            0.0      0.0
# ms_pod_homolkou                   1.0         0.0            0.0      0.0
# ms_vrchlickeho                    0.0         0.0            0.0      0.0
# ms_drasarova                      0.0         0.0            0.0      0.0
# ms_na_machovne                    0.0         0.0            0.0      0.0
# zimni_stad                        0.0         0.0            0.0      0.0
# parkovaci_dum                     0.0         0.0            0.0      0.0
# radnice                           0.0         1.0            0.0      0.0
# ms_tovarni                        0.0         0.0            0.0      0.0
# dum_pro_duchodce                  0.0         0.0            0.0      0.0
# plavecky_areal                    1.0         0.0            0.0      0.0
# pristavba_preislerova             0.0         0.0            0.0      0.0
#
#                        ms_tovarni  dum_pro_duchodce  plavecky_areal  \
# zs_preislerova                0.0               0.0             0.0
# zs_komenskeho                 0.0               0.0             0.0
# ms_preislerova                0.0               0.0             0.0
# ms_pod_homolkou               0.0               0.0             0.0
# ms_vrchlickeho                0.0               0.0             0.0
# ms_drasarova                  0.0               0.0             0.0
# ms_na_machovne                0.0               0.0             0.0
# zimni_stad                    0.0               0.0             0.0
# parkovaci_dum                 0.0               0.0             0.0
# radnice                       0.0               0.0             0.0
# ms_tovarni                    0.0               0.0             0.0
# dum_pro_duchodce              0.0               0.0             0.0
# plavecky_areal                0.0               0.0             0.0
# pristavba_preislerova         0.0               0.0             0.0
#
#                        pristavba_preislerova
# zs_preislerova                           1.0
# zs_komenskeho                            0.0
# ms_preislerova                           0.0
# ms_pod_homolkou                          1.0
# ms_vrchlickeho                           0.0
# ms_drasarova                             0.0
# ms_na_machovne                           0.0
# zimni_stad                               0.0
# parkovaci_dum                            0.0
# radnice                                  0.0
# ms_tovarni                               0.0
# dum_pro_duchodce                         0.0
# plavecky_areal                           1.0
# pristavba_preislerova                    0.0

# %%
best_M
# Out:
#                        zs_preislerova  zs_komenskeho  ms_preislerova  \
# zs_preislerova                    0.0            0.0             0.0
# zs_komenskeho                     0.0            0.0             1.0
# ms_preislerova                    0.0            0.0             0.0
# ms_pod_homolkou                   2.0            0.0             0.0
# ms_vrchlickeho                    0.0            0.0             0.0
# ms_drasarova                      0.0            0.0             0.0
# ms_na_machovne                    0.0            0.0             0.0
# zimni_stad                        2.0            0.0             3.0
# parkovaci_dum                     0.0            0.0             0.0
# radnice                           0.0            0.0             2.0
# ms_tovarni                        0.0            0.0             2.0
# dum_pro_duchodce                  0.0            0.0             1.0
# plavecky_areal                    0.0            0.0             4.0
# pristavba_preislerova             0.0            0.0             0.0
#
#                        ms_pod_homolkou  ms_vrchlickeho  ms_drasarova  \
# zs_preislerova                     2.0             5.0           1.0
# zs_komenskeho                      0.0             0.0           0.0
# ms_preislerova                     0.0             0.0           0.0
# ms_pod_homolkou                    0.0             5.0           3.0
# ms_vrchlickeho                     0.0             0.0           0.0
# ms_drasarova                       0.0             0.0           0.0
# ms_na_machovne                     0.0             0.0           0.0
# zimni_stad                         1.0             0.0           0.0
# parkovaci_dum                      0.0             0.0           0.0
# radnice                            0.0             0.0           0.0
# ms_tovarni                         1.0             0.0           0.0
# dum_pro_duchodce                   0.0             0.0           0.0
# plavecky_areal                     0.0             1.0           3.0
# pristavba_preislerova              0.0             0.0           0.0
#
#                        ms_na_machovne  zimni_stad  parkovaci_dum  radnice  \
# zs_preislerova                    4.0         0.0            0.0      0.0
# zs_komenskeho                     0.0         0.0            2.0      0.0
# ms_preislerova                    0.0         0.0            0.0      0.0
# ms_pod_homolkou                   1.0         0.0            0.0      0.0
# ms_vrchlickeho                    0.0         0.0            0.0      0.0
# ms_drasarova                      0.0         0.0            0.0      0.0
# ms_na_machovne                    0.0         0.0            0.0      0.0
# zimni_stad                        0.0         0.0            0.0      0.0
# parkovaci_dum                     0.0         0.0            0.0      0.0
# radnice                           0.0         1.0            0.0      0.0
# ms_tovarni                        0.0         0.0            0.0      0.0
# dum_pro_duchodce                  0.0         0.0            0.0      0.0
# plavecky_areal                    2.0         0.0            0.0      0.0
# pristavba_preislerova             0.0         0.0            0.0      0.0
#
#                        ms_tovarni  dum_pro_duchodce  plavecky_areal  \
# zs_preislerova                0.0               0.0             0.0
# zs_komenskeho                 0.0               0.0             0.0
# ms_preislerova                0.0               0.0             0.0
# ms_pod_homolkou               0.0               0.0             0.0
# ms_vrchlickeho                0.0               0.0             0.0
# ms_drasarova                  0.0               0.0             0.0
# ms_na_machovne                0.0               0.0             0.0
# zimni_stad                    0.0               0.0             0.0
# parkovaci_dum                 0.0               0.0             0.0
# radnice                       0.0               0.0             0.0
# ms_tovarni                    0.0               0.0             0.0
# dum_pro_duchodce              0.0               0.0             0.0
# plavecky_areal                0.0               0.0             0.0
# pristavba_preislerova         0.0               0.0             0.0
#
#                        pristavba_preislerova
# zs_preislerova                           3.0
# zs_komenskeho                            0.0
# ms_preislerova                           0.0
# ms_pod_homolkou                          4.0
# ms_vrchlickeho                           0.0
# ms_drasarova                             0.0
# ms_na_machovne                           0.0
# zimni_stad                               0.0
# parkovaci_dum                            0.0
# radnice                                  0.0
# ms_tovarni                               0.0
# dum_pro_duchodce                         0.0
# plavecky_areal                           5.0
# pristavba_preislerova                    0.0

# %%
def generate_preferences(producers, consumers, n: int = 5) -> pd.DataFrame:
    """
    Create a (consumers × producers) preference matrix.

    Parameters
    ----------
    producers : list[str]
        Column labels.
    consumers : list[str]
        Row labels.
    n : int, default 5
        Maximum number of producers a consumer can rank (must be ≥ 1).

    Returns
    -------
    pd.DataFrame
        Integer preference scores where 0 means “not ranked”.
        Shape = (len(consumers), len(producers)).
    """
    if n < 1:
        raise ValueError("n must be a positive integer")

    # Never sample more producers than exist.
    n = min(n, len(producers))

    rows = {}
    for consumer in consumers:
        # Choose up to n producers for this consumer (no duplicates).
        chosen = np.random.choice(producers, size=n, replace=False)
        # Randomly permute the ranks 1..n so each appears at most once.
        ranks = np.random.permutation(np.arange(1, n + 1))

        # Build a row: start with zeros, then fill the chosen producers.
        row = dict.fromkeys(producers, 0)
        row.update(zip(chosen, ranks))
        rows[consumer] = row

    # Orient as consumers (index) × producers (columns).
    return pd.DataFrame.from_dict(rows, orient="index", columns=producers)

# %%
import utils2 as ut

data_dir = '/home/miro/Bachelor/BT/data/outputs/'
excess_monthly, deficit_monthly = ut.load_excess_deficit(data_dir)
excess, deficit = ut.prepare_data(excess_monthly, deficit_monthly, 4, 0, 25, all_data=True)
producers = excess.columns
consumers = deficit.columns
preference_df = generate_preferences(producers, consumers)

# %%
generate_preferences(producers, consumers, 1).sum(axis=0)
# Out:
# zs_preislerova           2
# zs_komenskeho            0
# ms_preislerova           1
# ms_pod_homolkou          1
# ms_vrchlickeho           0
# ms_drasarova             2
# ms_na_machovne           1
# zimni_stad               2
# parkovaci_dum            0
# radnice                  1
# ms_tovarni               0
# dum_pro_duchodce         3
# plavecky_areal           0
# pristavba_preislerova    1
# dtype: int64
